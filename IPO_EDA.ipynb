# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams["figure.figsize"] = (15,7)

# %%
df = pd.read_csv('/Users/apple/Downloads/IPO.csv')
df
# Out:
#          Date         IPO_Name  Issue_Size(crores)     QIB     HNI     RII  \
# 0    26-11-21  Tarsons Product             1030.22    1.06    3.40    2.49
# 1    23-11-21      Latent View              622.11  145.48  850.66  119.44
# 2    18-11-21   Sapphire Foods             2073.00    3.11    2.34    5.25
# 3    18-11-21    One 97(Paytm)            18915.90    2.79    0.24    1.66
# 4    15-11-21  SJS Enterprises              816.57    1.42    2.32    1.38
# ..        ...              ...                 ...     ...     ...     ...
# 283  19-02-10      Thangamayil                0.00    0.52    1.52    2.26
# 284  15-02-10    Syncom Health               56.25    0.99   16.60    6.25
# 285  15-02-10  Vascon Engineer              199.80    1.12    3.65    0.62
# 286  08-02-10    Jubilant Food              328.70   59.39   51.95    3.79
# 287  03-02-10    Infinite Comp              189.80   48.44  106.02   11.08
#
# ...

# %%
df.describe()
# Out:
#        Issue_Size(crores)         QIB         HNI         RII  Issue_price  \
# count          288.000000  288.000000  288.000000  288.000000   288.000000
# mean          1118.383750   24.834688   71.413646    8.341181   368.913194
# std           2160.932743   37.837647  142.500596   14.159700   361.287606
# min              0.000000    0.000000    0.000000    0.000000     0.000000
# 25%            156.142500    1.147500    1.210000    1.367500   113.750000
# 50%            474.000000    4.810000    5.075000    3.405000   242.500000
# 75%           1049.480000   35.492500   73.295000    8.535000   522.500000
# max          18915.900000  176.850000  958.070000  119.440000  2150.000000
#
#        Listing_Open  Listing_Close  Listing_Gains(%)  Current_gains
# count    288.000000     288.000000        288.000000     286.000000
# mean     438.374653     396.502917          5.993056      65.616573
# std      458.703932     439.609061         49.354577     261.408128
# ...

# %%
df.isna().sum()
# Out:
# Date                  0
# IPO_Name              0
# Issue_Size(crores)    0
# QIB                   0
# HNI                   0
# RII                   0
# Issue_price           0
# Listing_Open          0
# Listing_Close         0
# Listing_Gains(%)      0
# CMP                   0
# Current_gains         2
# dtype: int64

# %%
len(df)
# Out:
# 288

# %%
df = df.sort_values('Current_gains',ascending= False)
df.head()
df_top_20 = df[:20]
df_bottom_20 = df[-20:]

# %%
df['year'] = df['Date'].apply(lambda x:x.split('-')[2])
df
# Out:
#          Date         IPO_Name  Issue_Size(crores)     QIB     HNI    RII  \
# 286  08-02-10    Jubilant Food              328.70   59.39   51.95   3.79
# 283  19-02-10      Thangamayil                0.00    0.52    1.52   2.26
# 127  21-03-17  Avenue Supermar             1870.00  144.61  277.74   7.30
# 271  06-04-10       Persistent              168.01  144.43  107.73  21.69
# 118  30-06-17             CDSL              523.99  148.71  563.03  23.83
# ..        ...              ...                 ...     ...     ...    ...
# 270  09-04-10     Shree Ganesh              385.29    1.38    6.13   1.39
# 235  27-10-10       BS Limited              197.36    0.52    3.16   1.04
# 186  18-07-12     VKS Projects               55.00    1.15    0.38   1.13
# 71   08-05-19           Neogen              131.48   30.49  113.88  16.06
# 85   04-04-18  Mishra Dhatu Ni              438.38    1.96    0.12   0.72
#
#      Issue_price  Listing_Open  Listing_Close  Listing_Gains(%)       CMP  \
# ...

# %%
df.year.value_counts()
# Out:
# 10    60
# 21    52
# 17    35
# 11    35
# 16    25
# 15    20
# 18    17
# 20    13
# 19    13
# 12    11
# 14     5
# 13     2
# Name: year, dtype: int64

# %%
OutLet_Num = df.year.value_counts()
chart = sns.barplot(x=OutLet_Num.index, y=OutLet_Num)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
plt.show()

# %%
chart = sns.barplot(x=df_top_20.IPO_Name, y=df_top_20['Current_gains'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
plt.show()

# %%
chart = sns.barplot(x=df_bottom_20.IPO_Name, y=df_bottom_20['Current_gains'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
plt.show()

# %%
pd.pivot_table(df, index = 'IPO_Name', values = 'HNI').sort_values('HNI', ascending = False)[:20]
# Out:
#                     HNI
# IPO_Name
# Apollo Micro Sy  958.07
# Latent View      850.66
# Mazagon Dock     678.88
# Capacite Infra   638.05
# Bectors Food     620.86
# CDSL             563.03
# MTAR Tech        522.35
# Amber Enterpris  519.26
# Salasar Techno   487.18
# Ujjivan Small    473.00
# Chemcon Special  449.14
# Paras Defence    435.14
# Astron Paper &   396.99
# Advanced Enzyme  393.10
# Quess Corp       392.21
# Rolex Rings      360.11
# IRCTC            354.52
# Burger King      354.11
# Happiest Minds   351.46
# Dixon Technolog  345.62

# %%
pd.pivot_table(df, index = 'IPO_Name', values = 'Issue_Size(crores)').sort_values('Issue_Size(crores)', ascending = False)[:20]
# Out:
#                  Issue_Size(crores)
# IPO_Name
# One 97(Paytm)              18915.90
# Coal India                 15475.00
# General Insuran            11372.00
# SBI Card                   10286.20
# Zomato                      9375.00
# HDFC Life                   8695.01
# SBI Life Insura             8400.00
# PowerGrid InvIT             7734.99
# Gland                       6479.55
# PB Fintech                  6273.50
# ICICI Prudentia             6057.00
# ICICI Lombard               5700.94
# Sona BLW                    5550.00
# FSN E-Co(Nykaa)             5375.00
# Nuvoco Vistas               5089.29
# Embassy Office              4750.00
# IRFC                        4633.00
# INDUS TOWERS                4533.60
# Bandhan Bank                4473.00
# Hindustan Aeron             4229.00
